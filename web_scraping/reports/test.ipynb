# %%
import json
from selenium import webdriver
from selenium.webdriver.chrome.service import Service

from webdriver_manager.chrome import ChromeDriverManager

# %%
options = webdriver.ChromeOptions()
options.set_capability(
    'goog:loggingPrefs', {"performance": "ALL", "browser": "ALL"}
)

# Use this for newer Selenium versions
driver = webdriver.Chrome(options=options)

# %%
driver.set_page_load_timeout(20)

try:
    driver.get('https://www.sofascore.com/football/match/manchester-united-leicester-city/GK#id:12437027,tab:statistics')
except:
    print ("error")

driver.execute_script("window.scroll(0, document.body.scrollHeight);")

# %%
logs_raw = driver.get_log("performance")

# %%
logs = [json.loads(lr['message'])['message'] for lr in logs_raw]
logs[0]
# Out:
# {'method': 'Page.frameStartedNavigating',
#  'params': {'frameId': 'F151E60319D815469E2F9E1E8A4E6256',
#   'loaderId': '395788ED753D3FAD827FE41C8627D9E9',
#   'navigationType': 'differentDocument',
#   'url': 'https://www.sofascore.com/football/match/manchester-united-leicester-city/GK#id:12437027,tab:statistics'}}

# %%
for x in logs: 
    if 'shotmap' in x['params'].get('headers', {}).get(':path',''):
        print(x['params'].get('headers', {}).get(':path',''))
        break
# Out:
# 1675

# %%
shotmap = json.loads (driver.execute_cdp_cmd('Network.getResponseBody',{'requestId': x['params']['requestId']})['body'])['shotmap']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 shotmap = json.loads (driver.execute_cdp_cmd('Network.getResponseBody',{'requestId': x['params']['requestId']})['body'])['shotmap']
#
# KeyError: 'shotmap'

# %%
shotmap
# Out:
# [{'player': {'name': 'Jamie Vardy',
#    'slug': 'jamie-vardy',
#    'shortName': 'J. Vardy',
#    'position': 'F',
#    'jerseyNumber': '9',
#    'userCount': 21184,
#    'id': 173827,
#    'fieldTranslations': {'nameTranslation': {'ar': 'جيمي فاردي',
#      'hi': 'जेमी वर्डी',
#      'bn': 'জেমি ভার্ডি'},
#     'shortNameTranslation': {'ar': 'ج. فاردي',
#      'hi': 'जे. वर्डी',
#      'bn': 'জে. ভার্ডি'}}},
#   'isHome': True,
#   'shotType': 'save',
#   'situation': 'set-piece',
#   'playerCoordinates': {'x': 3.8, 'y': 35.8, 'z': 0},
#   'bodyPart': 'left-foot',
#   'goalMouthLocation': 'low-centre',
#   'goalMouthCoordinates': {'x': 0, 'y': 51.1, 'z': 17.7},
#   'blockCoordinates': {'x': 0.59999999999999, 'y': 45.7, 'z': 0},
#   'xg': 0.16090998053551,
#   'xgot': 0.13185575604439,
#   'id': 4600165,
#   'time': 90,
#   'addedTime': 7,
#   'timeSeconds': 5775,
#   'draw': {'start': {'x': 35.8, 'y': 3.8},
#    'block': {'x': 45.7, 'y': 0.59999999999999},
#    'end': {'x': 48.9, 'y': 0},
#    'goal': {'x': 48.9, 'y': 82.3}},
#   'reversedPeriodTime': 1,
#   'reversedPeriodTimeSeconds': 525,
#   'periodTimeSeconds': 375,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Harry Winks',
#    'slug': 'harry-winks',
#    'shortName': 'H. Winks',
#    'position': 'M',
#    'jerseyNumber': '8',
#    'userCount': 1468,
#    'id': 545780,
#    'fieldTranslations': {'nameTranslation': {'ar': 'هاري وينكس',
#      'hi': 'हैरी विंक्स',
#      'bn': 'হ্যারি উইঙ্কস'},
#     'shortNameTranslation': {'ar': 'ه. وينكس',
#      'hi': 'एच. विंक्स',
#      'bn': 'এইচ. উইঙ্কস'}}},
#   'isHome': True,
#   'shotType': 'save',
#   'situation': 'regular',
#   'playerCoordinates': {'x': 25.9, 'y': 46.4, 'z': 0},
#   'bodyPart': 'left-foot',
#   'goalMouthLocation': 'low-centre',
#   'goalMouthCoordinates': {'x': 0, 'y': 50, 'z': 1.9},
#   'blockCoordinates': {'x': 1.6, 'y': 50.5, 'z': 0},
#   'xg': 0.025512738153338,
#   'xgot': 0.012240036390722,
#   'id': 4600161,
#   'time': 90,
#   'addedTime': 5,
#   'timeSeconds': 5692,
#   'draw': {'start': {'x': 46.4, 'y': 25.9},
#    'block': {'x': 50.5, 'y': 1.6},
#    'end': {'x': 50, 'y': 0},
#    'goal': {'x': 50, 'y': 98.1}},
#   'reversedPeriodTime': 1,
#   'reversedPeriodTimeSeconds': 608,
#   'periodTimeSeconds': 292,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Bruno Fernandes',
#    'slug': 'bruno-fernandes',
#    'shortName': 'B. Fernandes',
#    'position': 'M',
#    'jerseyNumber': '8',
#    'userCount': 182893,
#    'id': 288205,
#    'fieldTranslations': {'nameTranslation': {'ar': 'برونو فيرنانديز',
#      'hi': 'ब्रूनो फर्नांडीस',
#      'bn': 'ব্রুনো ফার্নান্দেস'},
#     'shortNameTranslation': {'ar': 'ب. فرنانديز',
#      'hi': 'बी. फर्नांडीस',
#      'bn': 'বি. ফার্নান্দেস'}}},
#   'isHome': False,
#   'shotType': 'goal',
#   'goalType': 'regular',
#   'situation': 'assisted',
#   'playerCoordinates': {'x': 18.7, 'y': 52.8, 'z': 0},
#   'bodyPart': 'right-foot',
#   'goalMouthLocation': 'low-left',
#   'goalMouthCoordinates': {'x': 0, 'y': 54.1, 'z': 14.6},
#   'xg': 0.10261054337025,
#   'xgot': 0.63882112503052,
#   'id': 4600149,
#   'time': 90,
#   'timeSeconds': 5349,
#   'draw': {'start': {'x': 52.8, 'y': 18.7},
#    'end': {'x': 45.9, 'y': 0},
#    'goal': {'x': 45.9, 'y': 85.4}},
#   'reversedPeriodTime': 1,
#   'reversedPeriodTimeSeconds': 51,
#   'periodTimeSeconds': 2649,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Casemiro',
#    'firstName': '',
#    'lastName': '',
#    'slug': 'casemiro',
#    'shortName': 'Casemiro',
#    'position': 'M',
#    'jerseyNumber': '18',
#    'userCount': 111981,
#    'id': 122951,
#    'fieldTranslations': {'nameTranslation': {'ar': 'كاسيميرو',
#      'hi': 'कैसेमिरो',
#      'bn': 'ক্যাসেমিরো'},
#     'shortNameTranslation': {'ar': 'كاسيميرو',
#      'hi': 'कैसेमिरो',
#      'bn': 'ক্যাসেমিরো'}}},
#   'isHome': False,
#   'shotType': 'block',
#   'situation': 'assisted',
#   'playerCoordinates': {'x': 26.8, 'y': 57.5, 'z': 0},
#   'bodyPart': 'right-foot',
#   'goalMouthLocation': 'low-centre',
#   'goalMouthCoordinates': {'x': 0, 'y': 51.4, 'z': 6.9},
#   'blockCoordinates': {'x': 12, 'y': 53.4, 'z': 0},
#   'xg': 0.020909611135721,
#   'xgot': 0,
#   'id': 4600106,
#   'time': 79,
#   'timeSeconds': 4707,
#   'draw': {'start': {'x': 57.5, 'y': 26.8},
#    'block': {'x': 53.4, 'y': 12},
#    'end': {'x': 48.6, 'y': 0},
#    'goal': {'x': 48.6, 'y': 93.1}},
#   'reversedPeriodTime': 12,
#   'reversedPeriodTimeSeconds': 693,
#   'periodTimeSeconds': 2007,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Facundo Buonanotte',
#    'firstName': 'Facundo Buonanotte',
#    'lastName': '',
#    'slug': 'facundo-buonanotte',
#    'shortName': 'F. Buonanotte',
#    'position': 'M',
#    'jerseyNumber': '40',
#    'userCount': 6902,
#    'id': 1117025,
#    'fieldTranslations': {'nameTranslation': {'ar': 'فاكوندو بونانوتي',
#      'hi': 'फ़ाकंडो बुओनानोट्टे',
#      'bn': 'ফ্যাকুন্ডো বুওনানোত্তে'},
#     'shortNameTranslation': {'ar': 'ف. بونانوتي',
#      'hi': 'एफ. बुओनानोट्टे',
#      'bn': 'এফ. বুওনানোট'}}},
#   'isHome': True,
#   'shotType': 'block',
#   'situation': 'assisted',
#   'playerCoordinates': {'x': 10.7, 'y': 53, 'z': 0},
#   'bodyPart': 'right-foot',
#   'goalMouthLocation': 'low-centre',
#   'goalMouthCoordinates': {'x': 0, 'y': 50.6, 'z': 4.2},
#   'blockCoordinates': {'x': 7.1, 'y': 52.3, 'z': 0},
#   'xg': 0.16043667495251,
#   'xgot': 0,
#   'id': 4600095,
#   'time': 75,
#   'timeSeconds': 4483,
#   'draw': {'start': {'x': 53, 'y': 10.7},
#    'block': {'x': 52.3, 'y': 7.1},
#    'end': {'x': 49.4, 'y': 0},
#    'goal': {'x': 49.4, 'y': 95.8}},
#   'reversedPeriodTime': 16,
#   'reversedPeriodTimeSeconds': 917,
#   'periodTimeSeconds': 1783,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Luke Thomas',
#    'slug': 'luke-thomas',
#    'shortName': 'L. Thomas',
#    'position': 'D',
#    'jerseyNumber': '33',
#    'userCount': 497,
#    'id': 991584,
#    'fieldTranslations': {'nameTranslation': {'ar': 'لوك توماس',
#      'hi': 'ल्यूक थॉमस',
#      'bn': 'লুক থমাস'},
#     'shortNameTranslation': {'ar': 'ل. توماس',
#      'hi': 'एल. थॉमस',
#      'bn': 'এল. থমাস'}}},
#   'isHome': True,
#   'shotType': 'block',
#   'situation': 'assisted',
#   'playerCoordinates': {'x': 25.9, 'y': 41.9, 'z': 0},
#   'bodyPart': 'left-foot',
#   'goalMouthLocation': 'low-centre',
#   'goalMouthCoordinates': {'x': 0, 'y': 50.1, 'z': 19},
#   'blockCoordinates': {'x': 24.2, 'y': 42.4, 'z': 0},
#   'xg': 0.016907373443246,
#   'xgot': 0,
#   'id': 4600075,
#   'time': 70,
#   'timeSeconds': 4163,
#   'draw': {'start': {'x': 41.9, 'y': 25.9},
#    'block': {'x': 42.4, 'y': 24.2},
#    'end': {'x': 49.9, 'y': 0},
#    'goal': {'x': 49.9, 'y': 81}},
#   'reversedPeriodTime': 21,
#   'reversedPeriodTimeSeconds': 1237,
#   'periodTimeSeconds': 1463,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Alejandro Garnacho',
#    'firstName': '',
#    'lastName': '',
#    'slug': 'alejandro-garnacho',
#    'shortName': 'A. Garnacho',
#    'position': 'M',
#    'jerseyNumber': '17',
#    'userCount': 147677,
#    'id': 1135873,
#    'fieldTranslations': {'nameTranslation': {'ar': 'أليخاندرو غارناتشو',
#      'hi': 'एलेजांद्रो गार्नाचो',
#      'bn': 'আলেজান্দ্রো গার্নাচো'},
#     'shortNameTranslation': {'ar': 'أ. غارناتشو',
#      'hi': 'ए. गार्नाचो',
#      'bn': 'এ. গার্নাচো'}}},
#   'isHome': False,
#   'shotType': 'goal',
#   'goalType': 'regular',
#   'situation': 'assisted',
#   'playerCoordinates': {'x': 12, 'y': 59.1, 'z': 0},
#   'bodyPart': 'right-foot',
#   'goalMouthLocation': 'low-right',
#   'goalMouthCoordinates': {'x': 0, 'y': 46.3, 'z': 7},
#   'xg': 0.062079336494207,
#   'xgot': 0.24153129756451,
#   'id': 4600066,
#   'time': 67,
#   'timeSeconds': 4013,
#   'draw': {'start': {'x': 59.1, 'y': 12},
#    'end': {'x': 53.7, 'y': 0},
#    'goal': {'x': 53.7, 'y': 93}},
#   'reversedPeriodTime': 24,
#   'reversedPeriodTimeSeconds': 1387,
#   'periodTimeSeconds': 1313,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Diogo Dalot',
#    'firstName': '',
#    'lastName': '',
#    'slug': 'diogo-dalot',
#    'shortName': 'D. Dalot',
#    'position': 'D',
#    'jerseyNumber': '20',
#    'userCount': 21092,
#    'id': 843200,
#    'fieldTranslations': {'nameTranslation': {'ar': 'ديوغو دالوت',
#      'hi': 'डिओगो डालोत',
#      'bn': 'ডিওগো ডালট'},
#     'shortNameTranslation': {'ar': 'د. دالوت',
#      'hi': 'डी. डालोत',
#      'bn': 'ডি. ডালট'}}},
#   'isHome': False,
#   'shotType': 'block',
#   'situation': 'assisted',
#   'playerCoordinates': {'x': 14, 'y': 32, 'z': 0},
#   'bodyPart': 'right-foot',
#   'goalMouthLocation': 'low-centre',
#   'goalMouthCoordinates': {'x': 0, 'y': 51.5, 'z': 19},
#   'blockCoordinates': {'x': 12.7, 'y': 33.6, 'z': 0},
#   'xg': 0.031824562698603,
#   'xgot': 0,
#   'id': 4600068,
#   'time': 67,
#   'timeSeconds': 3992,
#   'draw': {'start': {'x': 32, 'y': 14},
#    'block': {'x': 33.6, 'y': 12.7},
#    'end': {'x': 48.5, 'y': 0},
#    'goal': {'x': 48.5, 'y': 81}},
#   'reversedPeriodTime': 24,
#   'reversedPeriodTimeSeconds': 1408,
#   'periodTimeSeconds': 1292,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Bruno Fernandes',
#    'slug': 'bruno-fernandes',
#    'shortName': 'B. Fernandes',
#    'position': 'M',
#    'jerseyNumber': '8',
#    'userCount': 182893,
#    'id': 288205,
#    'fieldTranslations': {'nameTranslation': {'ar': 'برونو فيرنانديز',
#      'hi': 'ब्रूनो फर्नांडीस',
#      'bn': 'ব্রুনো ফার্নান্দেস'},
#     'shortNameTranslation': {'ar': 'ب. فرنانديز',
#      'hi': 'बी. फर्नांडीस',
#      'bn': 'বি. ফার্নান্দেস'}}},
#   'isHome': False,
#   'shotType': 'block',
#   'situation': 'assisted',
#   'playerCoordinates': {'x': 31, 'y': 36.8, 'z': 0},
#   'bodyPart': 'right-foot',
#   'goalMouthLocation': 'low-centre',
#   'goalMouthCoordinates': {'x': 0, 'y': 51.7, 'z': 19},
#   'blockCoordinates': {'x': 28.5, 'y': 37.7, 'z': 0},
#   'xg': 0.011741313152015,
#   'xgot': 0,
#   'id': 4600063,
#   'time': 66,
#   'timeSeconds': 3907,
#   'draw': {'start': {'x': 36.8, 'y': 31},
#    'block': {'x': 37.7, 'y': 28.5},
#    'end': {'x': 48.3, 'y': 0},
#    'goal': {'x': 48.3, 'y': 81}},
#   'reversedPeriodTime': 25,
#   'reversedPeriodTimeSeconds': 1493,
#   'periodTimeSeconds': 1207,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Alejandro Garnacho',
#    'firstName': '',
#    'lastName': '',
#    'slug': 'alejandro-garnacho',
#    'shortName': 'A. Garnacho',
#    'position': 'M',
#    'jerseyNumber': '17',
#    'userCount': 147677,
#    'id': 1135873,
#    'fieldTranslations': {'nameTranslation': {'ar': 'أليخاندرو غارناتشو',
#      'hi': 'एलेजांद्रो गार्नाचो',
#      'bn': 'আলেজান্দ্রো গার্নাচো'},
#     'shortNameTranslation': {'ar': 'أ. غارناتشو',
#      'hi': 'ए. गार्नाचो',
#      'bn': 'এ. গার্নাচো'}}},
#   'isHome': False,
#   'shotType': 'save',
#   'situation': 'corner',
#   'playerCoordinates': {'x': 13.8, 'y': 70.3, 'z': 0},
#   'bodyPart': 'right-foot',
#   'goalMouthLocation': 'low-left',
#   'goalMouthCoordinates': {'x': 0, 'y': 52.1, 'z': 4.4},
#   'blockCoordinates': {'x': 1.2, 'y': 52.2, 'z': 0},
#   'xg': 0.020430004224181,
#   'xgot': 0.054308965802193,
#   'id': 4600054,
#   'time': 62,
#   'timeSeconds': 3698,
#   'draw': {'start': {'x': 70.3, 'y': 13.8},
#    'block': {'x': 52.2, 'y': 1.2},
#    'end': {'x': 47.9, 'y': 0},
#    'goal': {'x': 47.9, 'y': 95.6}},
#   'reversedPeriodTime': 29,
#   'reversedPeriodTimeSeconds': 1702,
#   'periodTimeSeconds': 998,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Toby Collyer',
#    'firstName': 'Toby Collyer',
#    'lastName': '',
#    'slug': 'toby-collyer',
#    'shortName': 'T. Collyer',
#    'position': 'M',
#    'jerseyNumber': '43',
#    'userCount': 4521,
#    'id': 1084356},
#   'isHome': False,
#   'shotType': 'miss',
#   'situation': 'corner',
#   'playerCoordinates': {'x': 5.4, 'y': 48.5, 'z': 0},
#   'bodyPart': 'other',
#   'goalMouthLocation': 'right',
#   'goalMouthCoordinates': {'x': 0, 'y': 26.2, 'z': 11.1},
#   'blockCoordinates': {'x': 4, 'y': 53.8, 'z': 0},
#   'xg': 0.17188990116119,
#   'xgot': 0,
#   'id': 4600056,
#   'time': 62,
#   'timeSeconds': 3694,
#   'draw': {'start': {'x': 48.5, 'y': 5.4},
#    'block': {'x': 53.8, 'y': 4},
#    'end': {'x': 73.8, 'y': 0},
#    'goal': {'x': 73.8, 'y': 88.9}},
#   'reversedPeriodTime': 29,
#   'reversedPeriodTimeSeconds': 1706,
#   'periodTimeSeconds': 994,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Christian Eriksen',
#    'slug': 'christian-eriksen',
#    'shortName': 'C. Eriksen',
#    'position': 'M',
#    'jerseyNumber': '14',
#    'userCount': 30661,
#    'id': 105734,
#    'fieldTranslations': {'nameTranslation': {'ar': 'كريستيان إريكسن',
#      'hi': 'क्रिस्टियन एरिक्सन',
#      'bn': 'ক্রিশ্চিয়ান এরিকসেন'},
#     'shortNameTranslation': {'ar': 'ك. إريكسن',
#      'hi': 'सी. एरिक्सन',
#      'bn': 'সি. এরিকসেন'}}},
#   'isHome': False,
#   'shotType': 'block',
#   'situation': 'assisted',
#   'playerCoordinates': {'x': 23.5, 'y': 53.2, 'z': 0},
#   'bodyPart': 'right-foot',
#   'goalMouthLocation': 'low-centre',
#   'goalMouthCoordinates': {'x': 0, 'y': 50, 'z': 19},
#   'blockCoordinates': {'x': 22.5, 'y': 53.1, 'z': 0},
#   'xg': 0.023890597745776,
#   'xgot': 0,
#   'id': 4600053,
#   'time': 61,
#   'timeSeconds': 3642,
#   'draw': {'start': {'x': 53.2, 'y': 23.5},
#    'block': {'x': 53.1, 'y': 22.5},
#    'end': {'x': 50, 'y': 0},
#    'goal': {'x': 50, 'y': 81}},
#   'reversedPeriodTime': 30,
#   'reversedPeriodTimeSeconds': 1758,
#   'periodTimeSeconds': 942,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Christian Eriksen',
#    'slug': 'christian-eriksen',
#    'shortName': 'C. Eriksen',
#    'position': 'M',
#    'jerseyNumber': '14',
#    'userCount': 30661,
#    'id': 105734,
#    'fieldTranslations': {'nameTranslation': {'ar': 'كريستيان إريكسن',
#      'hi': 'क्रिस्टियन एरिक्सन',
#      'bn': 'ক্রিশ্চিয়ান এরিকসেন'},
#     'shortNameTranslation': {'ar': 'ك. إريكسن',
#      'hi': 'सी. एरिक्सन',
#      'bn': 'সি. এরিকসেন'}}},
#   'isHome': False,
#   'shotType': 'miss',
#   'situation': 'assisted',
#   'playerCoordinates': {'x': 28.4, 'y': 46.7, 'z': 0},
#   'bodyPart': 'right-foot',
#   'goalMouthLocation': 'close-left',
#   'goalMouthCoordinates': {'x': 0, 'y': 58.8, 'z': 6.9},
#   'blockCoordinates': {'x': 2.2, 'y': 43.1, 'z': 0},
#   'xg': 0.030677504837513,
#   'xgot': 0,
#   'id': 4600027,
#   'time': 56,
#   'timeSeconds': 3340,
#   'draw': {'start': {'x': 46.7, 'y': 28.4},
#    'block': {'x': 43.1, 'y': 2.2},
#    'end': {'x': 41.2, 'y': 0},
#    'goal': {'x': 41.2, 'y': 93.1}},
#   'reversedPeriodTime': 35,
#   'reversedPeriodTimeSeconds': 2060,
#   'periodTimeSeconds': 640,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Jamie Vardy',
#    'slug': 'jamie-vardy',
#    'shortName': 'J. Vardy',
#    'position': 'F',
#    'jerseyNumber': '9',
#    'userCount': 21184,
#    'id': 173827,
#    'fieldTranslations': {'nameTranslation': {'ar': 'جيمي فاردي',
#      'hi': 'जेमी वर्डी',
#      'bn': 'জেমি ভার্ডি'},
#     'shortNameTranslation': {'ar': 'ج. فاردي',
#      'hi': 'जे. वर्डी',
#      'bn': 'জে. ভার্ডি'}}},
#   'isHome': True,
#   'shotType': 'block',
#   'situation': 'assisted',
#   'playerCoordinates': {'x': 9.7, 'y': 42.5, 'z': 0},
#   'bodyPart': 'head',
#   'goalMouthLocation': 'low-centre',
#   'goalMouthCoordinates': {'x': 0, 'y': 50.1, 'z': 19},
#   'blockCoordinates': {'x': 8.4, 'y': 43.5, 'z': 0},
#   'xg': 0.035044740885496,
#   'xgot': 0,
#   'id': 4600039,
#   'time': 55,
#   'timeSeconds': 3272,
#   'draw': {'start': {'x': 42.5, 'y': 9.7},
#    'block': {'x': 43.5, 'y': 8.4},
#    'end': {'x': 49.9, 'y': 0},
#    'goal': {'x': 49.9, 'y': 81}},
#   'reversedPeriodTime': 36,
#   'reversedPeriodTimeSeconds': 2128,
#   'periodTimeSeconds': 572,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Boubakary Soumaré',
#    'firstName': '',
#    'lastName': '',
#    'slug': 'boubakary-soumare',
#    'shortName': 'B. Soumaré',
#    'position': 'M',
#    'jerseyNumber': '24',
#    'userCount': 1384,
#    'id': 887581,
#    'fieldTranslations': {'nameTranslation': {'ar': 'بوباكاري سوماري',
#      'hi': 'बौबाकरी सौमारे',
#      'bn': 'বুবাকারি সৌমারে'},
#     'shortNameTranslation': {'ar': 'ب. سوماري',
#      'hi': 'बी. सौमारे',
#      'bn': 'বি. সৌমারে'}}},
#   'isHome': True,
#   'shotType': 'block',
#   'situation': 'assisted',
#   'playerCoordinates': {'x': 21.6, 'y': 58.5, 'z': 0},
#   'bodyPart': 'right-foot',
#   'goalMouthLocation': 'low-centre',
#   'goalMouthCoordinates': {'x': 0, 'y': 50.2, 'z': 19},
#   'blockCoordinates': {'x': 18, 'y': 57, 'z': 0},
#   'xg': 0.035473864525557,
#   'xgot': 0,
#   'id': 4600025,
#   'time': 55,
#   'timeSeconds': 3265,
#   'draw': {'start': {'x': 58.5, 'y': 21.6},
#    'block': {'x': 57, 'y': 18},
#    'end': {'x': 49.8, 'y': 0},
#    'goal': {'x': 49.8, 'y': 81}},
#   'reversedPeriodTime': 36,
#   'reversedPeriodTimeSeconds': 2135,
#   'periodTimeSeconds': 565,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Patson Daka',
#    'firstName': '',
#    'lastName': '',
#    'slug': 'patson-daka',
#    'shortName': 'P. Daka',
#    'position': 'F',
#    'jerseyNumber': '20',
#    'userCount': 13154,
#    'id': 865057,
#    'fieldTranslations': {'nameTranslation': {'ar': 'باتسون داكا',
#      'hi': 'पैटसन डाका',
#      'bn': 'প্যাটসন ডাকা'},
#     'shortNameTranslation': {'ar': 'ب. داكا',
#      'hi': 'पी. डाका',
#      'bn': 'পি. ডাকা'}}},
#   'isHome': True,
#   'shotType': 'miss',
#   'situation': 'fast-break',
#   'playerCoordinates': {'x': 3.2, 'y': 60.5, 'z': 0},
#   'bodyPart': 'right-foot',
#   'goalMouthLocation': 'right',
#   'goalMouthCoordinates': {'x': 0, 'y': 36, 'z': 11.1},
#   'xg': 0.10129973292351,
#   'xgot': 0,
#   'id': 4599991,
#   'time': 48,
#   'timeSeconds': 2822,
#   'draw': {'start': {'x': 60.5, 'y': 3.2},
#    'end': {'x': 64, 'y': 0},
#    'goal': {'x': 64, 'y': 88.9}},
#   'reversedPeriodTime': 43,
#   'reversedPeriodTimeSeconds': 2578,
#   'periodTimeSeconds': 122,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Patson Daka',
#    'firstName': '',
#    'lastName': '',
#    'slug': 'patson-daka',
#    'shortName': 'P. Daka',
#    'position': 'F',
#    'jerseyNumber': '20',
#    'userCount': 13154,
#    'id': 865057,
#    'fieldTranslations': {'nameTranslation': {'ar': 'باتسون داكا',
#      'hi': 'पैटसन डाका',
#      'bn': 'প্যাটসন ডাকা'},
#     'shortNameTranslation': {'ar': 'ب. داكا',
#      'hi': 'पी. डाका',
#      'bn': 'পি. ডাকা'}}},
#   'isHome': True,
#   'shotType': 'miss',
#   'situation': 'assisted',
#   'playerCoordinates': {'x': 29.6, 'y': 46.8, 'z': 0},
#   'bodyPart': 'left-foot',
#   'goalMouthLocation': 'right',
#   'goalMouthCoordinates': {'x': 0, 'y': 38.8, 'z': 9.7},
#   'xg': 0.035557109862566,
#   'xgot': 0,
#   'id': 4599921,
#   'time': 44,
#   'timeSeconds': 2618,
#   'draw': {'start': {'x': 46.8, 'y': 29.6},
#    'end': {'x': 61.2, 'y': 0},
#    'goal': {'x': 61.2, 'y': 90.3}},
#   'reversedPeriodTime': 2,
#   'reversedPeriodTimeSeconds': 82,
#   'periodTimeSeconds': 2618,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Bilal El Khannouss',
#    'firstName': 'Bilal',
#    'lastName': 'El Khannouss',
#    'slug': 'bilal-el-khannouss',
#    'shortName': 'B. E. Khannouss',
#    'position': 'M',
#    'jerseyNumber': '11',
#    'userCount': 20639,
#    'id': 1126569,
#    'fieldTranslations': {'nameTranslation': {'ar': 'بلال الخنوس',
#      'hi': 'बिलाल अल खन्नौस',
#      'bn': 'বিলাল এল খানৌস'},
#     'shortNameTranslation': {'ar': 'ب. أ. خنوس',
#      'hi': 'बी.ई. खन्नौस',
#      'bn': 'বি. ই. খানৌস'}}},
#   'isHome': True,
#   'shotType': 'block',
#   'situation': 'regular',
#   'playerCoordinates': {'x': 13.2, 'y': 32.9, 'z': 0},
#   'bodyPart': 'right-foot',
#   'goalMouthLocation': 'low-centre',
#   'goalMouthCoordinates': {'x': 0, 'y': 51.3, 'z': 19},
#   'blockCoordinates': {'x': 8.3, 'y': 38.8, 'z': 0},
#   'xg': 0.060561802238226,
#   'xgot': 0,
#   'id': 4599917,
#   'time': 43,
#   'timeSeconds': 2579,
#   'draw': {'start': {'x': 32.9, 'y': 13.2},
#    'block': {'x': 38.8, 'y': 8.3},
#    'end': {'x': 48.7, 'y': 0},
#    'goal': {'x': 48.7, 'y': 81}},
#   'reversedPeriodTime': 3,
#   'reversedPeriodTimeSeconds': 121,
#   'periodTimeSeconds': 2579,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Patson Daka',
#    'firstName': '',
#    'lastName': '',
#    'slug': 'patson-daka',
#    'shortName': 'P. Daka',
#    'position': 'F',
#    'jerseyNumber': '20',
#    'userCount': 13154,
#    'id': 865057,
#    'fieldTranslations': {'nameTranslation': {'ar': 'باتسون داكا',
#      'hi': 'पैटसन डाका',
#      'bn': 'প্যাটসন ডাকা'},
#     'shortNameTranslation': {'ar': 'ب. داكا',
#      'hi': 'पी. डाका',
#      'bn': 'পি. ডাকা'}}},
#   'isHome': True,
#   'shotType': 'block',
#   'situation': 'assisted',
#   'playerCoordinates': {'x': 15.6, 'y': 43.8, 'z': 0},
#   'bodyPart': 'right-foot',
#   'goalMouthLocation': 'low-left',
#   'goalMouthCoordinates': {'x': 0, 'y': 52.3, 'z': 19},
#   'blockCoordinates': {'x': 10.3, 'y': 45.1, 'z': 0},
#   'xg': 0.14835047721863,
#   'xgot': 0,
#   'id': 4599916,
#   'time': 43,
#   'timeSeconds': 2577,
#   'draw': {'start': {'x': 43.8, 'y': 15.6},
#    'block': {'x': 45.1, 'y': 10.3},
#    'end': {'x': 47.7, 'y': 0},
#    'goal': {'x': 47.7, 'y': 81}},
#   'reversedPeriodTime': 3,
#   'reversedPeriodTimeSeconds': 123,
#   'periodTimeSeconds': 2577,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Bruno Fernandes',
#    'slug': 'bruno-fernandes',
#    'shortName': 'B. Fernandes',
#    'position': 'M',
#    'jerseyNumber': '8',
#    'userCount': 182893,
#    'id': 288205,
#    'fieldTranslations': {'nameTranslation': {'ar': 'برونو فيرنانديز',
#      'hi': 'ब्रूनो फर्नांडीस',
#      'bn': 'ব্রুনো ফার্নান্দেস'},
#     'shortNameTranslation': {'ar': 'ب. فرنانديز',
#      'hi': 'बी. फर्नांडीस',
#      'bn': 'বি. ফার্নান্দেস'}}},
#   'isHome': False,
#   'shotType': 'miss',
#   'situation': 'set-piece',
#   'playerCoordinates': {'x': 21.9, 'y': 46.4, 'z': 0},
#   'bodyPart': 'right-foot',
#   'goalMouthLocation': 'high',
#   'goalMouthCoordinates': {'x': 0, 'y': 44.2, 'z': 84.7},
#   'xg': 0.031974527984858,
#   'xgot': 0,
#   'id': 4599910,
#   'time': 41,
#   'timeSeconds': 2447,
#   'draw': {'start': {'x': 46.4, 'y': 21.9},
#    'end': {'x': 55.8, 'y': 0},
#    'goal': {'x': 55.8, 'y': 15.3}},
#   'reversedPeriodTime': 5,
#   'reversedPeriodTimeSeconds': 253,
#   'periodTimeSeconds': 2447,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Rasmus Højlund',
#    'slug': 'rasmus-hojlund',
#    'shortName': 'R. Højlund',
#    'position': 'F',
#    'jerseyNumber': '9',
#    'userCount': 71812,
#    'id': 1086417,
#    'fieldTranslations': {'nameTranslation': {'ar': 'راسموس هويجلوند',
#      'hi': 'रस्मस होजलंड',
#      'bn': 'রাসমাস হলান্ড'},
#     'shortNameTranslation': {'ar': 'راسموس هوجلوند',
#      'hi': 'रासमस होजलंड',
#      'bn': 'রাসমাস হলান্ড'}}},
#   'isHome': False,
#   'shotType': 'goal',
#   'goalType': 'regular',
#   'situation': 'fast-break',
#   'playerCoordinates': {'x': 8.3, 'y': 65.4, 'z': 0},
#   'bodyPart': 'right-foot',
#   'goalMouthLocation': 'low-left',
#   'goalMouthCoordinates': {'x': 0, 'y': 53.6, 'z': 2.5},
#   'xg': 0.13871614634991,
#   'xgot': 0.71319180727005,
#   'id': 4599830,
#   'time': 28,
#   'timeSeconds': 1639,
#   'draw': {'start': {'x': 65.4, 'y': 8.3},
#    'end': {'x': 46.4, 'y': 0},
#    'goal': {'x': 46.4, 'y': 97.5}},
#   'reversedPeriodTime': 18,
#   'reversedPeriodTimeSeconds': 1061,
#   'periodTimeSeconds': 1639,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Christian Eriksen',
#    'slug': 'christian-eriksen',
#    'shortName': 'C. Eriksen',
#    'position': 'M',
#    'jerseyNumber': '14',
#    'userCount': 30661,
#    'id': 105734,
#    'fieldTranslations': {'nameTranslation': {'ar': 'كريستيان إريكسن',
#      'hi': 'क्रिस्टियन एरिक्सन',
#      'bn': 'ক্রিশ্চিয়ান এরিকসেন'},
#     'shortNameTranslation': {'ar': 'ك. إريكسن',
#      'hi': 'सी. एरिक्सन',
#      'bn': 'সি. এরিকসেন'}}},
#   'isHome': False,
#   'shotType': 'post',
#   'situation': 'corner',
#   'playerCoordinates': {'x': 15.1, 'y': 20.3, 'z': 0},
#   'bodyPart': 'right-foot',
#   'goalMouthLocation': 'right',
#   'goalMouthCoordinates': {'x': 0, 'y': 44.7, 'z': 30.4},
#   'xg': 0.016547836363316,
#   'xgot': 0,
#   'id': 4599816,
#   'time': 23,
#   'timeSeconds': 1363,
#   'draw': {'start': {'x': 20.3, 'y': 15.1},
#    'end': {'x': 55.3, 'y': 0},
#    'goal': {'x': 55.3, 'y': 69.6}},
#   'reversedPeriodTime': 23,
#   'reversedPeriodTimeSeconds': 1337,
#   'periodTimeSeconds': 1363,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Bruno Fernandes',
#    'slug': 'bruno-fernandes',
#    'shortName': 'B. Fernandes',
#    'position': 'M',
#    'jerseyNumber': '8',
#    'userCount': 182893,
#    'id': 288205,
#    'fieldTranslations': {'nameTranslation': {'ar': 'برونو فيرنانديز',
#      'hi': 'ब्रूनो फर्नांडीस',
#      'bn': 'ব্রুনো ফার্নান্দেস'},
#     'shortNameTranslation': {'ar': 'ب. فرنانديز',
#      'hi': 'बी. फर्नांडीस',
#      'bn': 'বি. ফার্নান্দেস'}}},
#   'isHome': False,
#   'shotType': 'block',
#   'situation': 'regular',
#   'playerCoordinates': {'x': 18.5, 'y': 49.5, 'z': 0},
#   'bodyPart': 'right-foot',
#   'goalMouthLocation': 'low-right',
#   'goalMouthCoordinates': {'x': 0, 'y': 47.4, 'z': 19},
#   'blockCoordinates': {'x': 13.3, 'y': 50.4, 'z': 0},
#   'xg': 0.071820646524429,
#   'xgot': 0,
#   'id': 4599788,
#   'time': 22,
#   'timeSeconds': 1316,
#   'draw': {'start': {'x': 49.5, 'y': 18.5},
#    'block': {'x': 50.4, 'y': 13.3},
#    'end': {'x': 52.6, 'y': 0},
#    'goal': {'x': 52.6, 'y': 81}},
#   'reversedPeriodTime': 24,
#   'reversedPeriodTimeSeconds': 1384,
#   'periodTimeSeconds': 1316,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Alejandro Garnacho',
#    'firstName': '',
#    'lastName': '',
#    'slug': 'alejandro-garnacho',
#    'shortName': 'A. Garnacho',
#    'position': 'M',
#    'jerseyNumber': '17',
#    'userCount': 147677,
#    'id': 1135873,
#    'fieldTranslations': {'nameTranslation': {'ar': 'أليخاندرو غارناتشو',
#      'hi': 'एलेजांद्रो गार्नाचो',
#      'bn': 'আলেজান্দ্রো গার্নাচো'},
#     'shortNameTranslation': {'ar': 'أ. غارناتشو',
#      'hi': 'ए. गार्नाचो',
#      'bn': 'এ. গার্নাচো'}}},
#   'isHome': False,
#   'shotType': 'save',
#   'situation': 'corner',
#   'playerCoordinates': {'x': 21.4, 'y': 69.4, 'z': 0},
#   'bodyPart': 'right-foot',
#   'goalMouthLocation': 'low-centre',
#   'goalMouthCoordinates': {'x': 0, 'y': 49.3, 'z': 10.8},
#   'blockCoordinates': {'x': 2, 'y': 52.7, 'z': 0},
#   'xg': 0.017613371834159,
#   'xgot': 0.0098451506346464,
#   'id': 4599768,
#   'time': 19,
#   'timeSeconds': 1110,
#   'draw': {'start': {'x': 69.4, 'y': 21.4},
#    'block': {'x': 52.7, 'y': 2},
#    'end': {'x': 50.7, 'y': 0},
#    'goal': {'x': 50.7, 'y': 89.2}},
#   'reversedPeriodTime': 27,
#   'reversedPeriodTimeSeconds': 1590,
#   'periodTimeSeconds': 1110,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Manuel Ugarte',
#    'slug': 'manuel-ugarte',
#    'shortName': 'M. Ugarte',
#    'position': 'M',
#    'jerseyNumber': '25',
#    'userCount': 15689,
#    'id': 846425,
#    'fieldTranslations': {'nameTranslation': {'ar': 'مانويل أوغارتي',
#      'hi': 'मैनुअल उगार्टे',
#      'bn': 'ম্যানুয়েল উগার্তে'},
#     'shortNameTranslation': {'ar': 'م. أوغارتي',
#      'hi': 'एम. उगार्टे',
#      'bn': 'এম. উগার্তে'}}},
#   'isHome': False,
#   'shotType': 'miss',
#   'situation': 'assisted',
#   'playerCoordinates': {'x': 24.5, 'y': 31.9, 'z': 0},
#   'bodyPart': 'right-foot',
#   'goalMouthLocation': 'high-right',
#   'goalMouthCoordinates': {'x': 0, 'y': 40.2, 'z': 69.4},
#   'xg': 0.025978589430451,
#   'xgot': 0,
#   'id': 4599723,
#   'time': 11,
#   'timeSeconds': 629,
#   'draw': {'start': {'x': 31.9, 'y': 24.5},
#    'end': {'x': 59.8, 'y': 0},
#    'goal': {'x': 59.8, 'y': 30.6}},
#   'reversedPeriodTime': 35,
#   'reversedPeriodTimeSeconds': 2071,
#   'periodTimeSeconds': 629,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Manuel Ugarte',
#    'slug': 'manuel-ugarte',
#    'shortName': 'M. Ugarte',
#    'position': 'M',
#    'jerseyNumber': '25',
#    'userCount': 15689,
#    'id': 846425,
#    'fieldTranslations': {'nameTranslation': {'ar': 'مانويل أوغارتي',
#      'hi': 'मैनुअल उगार्टे',
#      'bn': 'ম্যানুয়েল উগার্তে'},
#     'shortNameTranslation': {'ar': 'م. أوغارتي',
#      'hi': 'एम. उगार्टे',
#      'bn': 'এম. উগার্তে'}}},
#   'isHome': False,
#   'shotType': 'miss',
#   'situation': 'throw-in-set-piece',
#   'playerCoordinates': {'x': 18.3, 'y': 69.2, 'z': 0},
#   'bodyPart': 'right-foot',
#   'goalMouthLocation': 'high',
#   'goalMouthCoordinates': {'x': 0, 'y': 46.1, 'z': 62.5},
#   'xg': 0.031524680554867,
#   'xgot': 0,
#   'id': 4599685,
#   'time': 9,
#   'timeSeconds': 499,
#   'draw': {'start': {'x': 69.2, 'y': 18.3},
#    'end': {'x': 53.9, 'y': 0},
#    'goal': {'x': 53.9, 'y': 37.5}},
#   'reversedPeriodTime': 37,
#   'reversedPeriodTimeSeconds': 2201,
#   'periodTimeSeconds': 499,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Rasmus Højlund',
#    'slug': 'rasmus-hojlund',
#    'shortName': 'R. Højlund',
#    'position': 'F',
#    'jerseyNumber': '9',
#    'userCount': 71812,
#    'id': 1086417,
#    'fieldTranslations': {'nameTranslation': {'ar': 'راسموس هويجلوند',
#      'hi': 'रस्मस होजलंड',
#      'bn': 'রাসমাস হলান্ড'},
#     'shortNameTranslation': {'ar': 'راسموس هوجلوند',
#      'hi': 'रासमस होजलंड',
#      'bn': 'রাসমাস হলান্ড'}}},
#   'isHome': False,
#   'shotType': 'miss',
#   'situation': 'assisted',
#   'playerCoordinates': {'x': 10.6, 'y': 50, 'z': 0},
#   'bodyPart': 'head',
#   'goalMouthLocation': 'right',
#   'goalMouthCoordinates': {'x': 0, 'y': 37.1, 'z': 20.8},
#   'blockCoordinates': {'x': 3.1, 'y': 57.4, 'z': 0},
#   'xg': 0.04499388858676,
#   'xgot': 0,
#   'id': 4599652,
#   'time': 6,
#   'timeSeconds': 340,
#   'draw': {'start': {'x': 50, 'y': 10.6},
#    'block': {'x': 57.4, 'y': 3.1},
#    'end': {'x': 62.9, 'y': 0},
#    'goal': {'x': 62.9, 'y': 79.2}},
#   'reversedPeriodTime': 40,
#   'reversedPeriodTimeSeconds': 2360,
#   'periodTimeSeconds': 340,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Jamie Vardy',
#    'slug': 'jamie-vardy',
#    'shortName': 'J. Vardy',
#    'position': 'F',
#    'jerseyNumber': '9',
#    'userCount': 21184,
#    'id': 173827,
#    'fieldTranslations': {'nameTranslation': {'ar': 'جيمي فاردي',
#      'hi': 'जेमी वर्डी',
#      'bn': 'জেমি ভার্ডি'},
#     'shortNameTranslation': {'ar': 'ج. فاردي',
#      'hi': 'जे. वर्डी',
#      'bn': 'জে. ভার্ডি'}}},
#   'isHome': True,
#   'shotType': 'save',
#   'situation': 'assisted',
#   'playerCoordinates': {'x': 11.4, 'y': 39.7, 'z': 0},
#   'bodyPart': 'right-foot',
#   'goalMouthLocation': 'high-left',
#   'goalMouthCoordinates': {'x': 0, 'y': 52.6, 'z': 20.9},
#   'blockCoordinates': {'x': 1, 'y': 47.7, 'z': 0},
#   'xg': 0.27265387773514,
#   'xgot': 0.23939791321754,
#   'id': 4599634,
#   'time': 4,
#   'timeSeconds': 205,
#   'draw': {'start': {'x': 39.7, 'y': 11.4},
#    'block': {'x': 47.7, 'y': 1},
#    'end': {'x': 47.4, 'y': 0},
#    'goal': {'x': 47.4, 'y': 79.1}},
#   'reversedPeriodTime': 42,
#   'reversedPeriodTimeSeconds': 2495,
#   'periodTimeSeconds': 205,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Rasmus Højlund',
#    'slug': 'rasmus-hojlund',
#    'shortName': 'R. Højlund',
#    'position': 'F',
#    'jerseyNumber': '9',
#    'userCount': 71812,
#    'id': 1086417,
#    'fieldTranslations': {'nameTranslation': {'ar': 'راسموس هويجلوند',
#      'hi': 'रस्मस होजलंड',
#      'bn': 'রাসমাস হলান্ড'},
#     'shortNameTranslation': {'ar': 'راسموس هوجلوند',
#      'hi': 'रासमस होजलंड',
#      'bn': 'রাসমাস হলান্ড'}}},
#   'isHome': False,
#   'shotType': 'miss',
#   'situation': 'throw-in-set-piece',
#   'playerCoordinates': {'x': 11.9, 'y': 43.4, 'z': 0},
#   'bodyPart': 'left-foot',
#   'goalMouthLocation': 'close-left',
#   'goalMouthCoordinates': {'x': 0, 'y': 57, 'z': 11.1},
#   'xg': 0.057159684598446,
#   'xgot': 0,
#   'id': 4599621,
#   'time': 1,
#   'timeSeconds': 54,
#   'draw': {'start': {'x': 43.4, 'y': 11.9},
#    'end': {'x': 43, 'y': 0},
#    'goal': {'x': 43, 'y': 88.9}},
#   'reversedPeriodTime': 45,
#   'reversedPeriodTimeSeconds': 2646,
#   'periodTimeSeconds': 54,
#   'incidentType': 'shot'}]

# %%
shotmap
# Out:
# [{'player': {'name': 'Jamie Vardy',
#    'slug': 'jamie-vardy',
#    'shortName': 'J. Vardy',
#    'position': 'F',
#    'jerseyNumber': '9',
#    'userCount': 21184,
#    'id': 173827,
#    'fieldTranslations': {'nameTranslation': {'ar': 'جيمي فاردي',
#      'hi': 'जेमी वर्डी',
#      'bn': 'জেমি ভার্ডি'},
#     'shortNameTranslation': {'ar': 'ج. فاردي',
#      'hi': 'जे. वर्डी',
#      'bn': 'জে. ভার্ডি'}}},
#   'isHome': True,
#   'shotType': 'save',
#   'situation': 'set-piece',
#   'playerCoordinates': {'x': 3.8, 'y': 35.8, 'z': 0},
#   'bodyPart': 'left-foot',
#   'goalMouthLocation': 'low-centre',
#   'goalMouthCoordinates': {'x': 0, 'y': 51.1, 'z': 17.7},
#   'blockCoordinates': {'x': 0.59999999999999, 'y': 45.7, 'z': 0},
#   'xg': 0.16090998053551,
#   'xgot': 0.13185575604439,
#   'id': 4600165,
#   'time': 90,
#   'addedTime': 7,
#   'timeSeconds': 5775,
#   'draw': {'start': {'x': 35.8, 'y': 3.8},
#    'block': {'x': 45.7, 'y': 0.59999999999999},
#    'end': {'x': 48.9, 'y': 0},
#    'goal': {'x': 48.9, 'y': 82.3}},
#   'reversedPeriodTime': 1,
#   'reversedPeriodTimeSeconds': 525,
#   'periodTimeSeconds': 375,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Harry Winks',
#    'slug': 'harry-winks',
#    'shortName': 'H. Winks',
#    'position': 'M',
#    'jerseyNumber': '8',
#    'userCount': 1468,
#    'id': 545780,
#    'fieldTranslations': {'nameTranslation': {'ar': 'هاري وينكس',
#      'hi': 'हैरी विंक्स',
#      'bn': 'হ্যারি উইঙ্কস'},
#     'shortNameTranslation': {'ar': 'ه. وينكس',
#      'hi': 'एच. विंक्स',
#      'bn': 'এইচ. উইঙ্কস'}}},
#   'isHome': True,
#   'shotType': 'save',
#   'situation': 'regular',
#   'playerCoordinates': {'x': 25.9, 'y': 46.4, 'z': 0},
#   'bodyPart': 'left-foot',
#   'goalMouthLocation': 'low-centre',
#   'goalMouthCoordinates': {'x': 0, 'y': 50, 'z': 1.9},
#   'blockCoordinates': {'x': 1.6, 'y': 50.5, 'z': 0},
#   'xg': 0.025512738153338,
#   'xgot': 0.012240036390722,
#   'id': 4600161,
#   'time': 90,
#   'addedTime': 5,
#   'timeSeconds': 5692,
#   'draw': {'start': {'x': 46.4, 'y': 25.9},
#    'block': {'x': 50.5, 'y': 1.6},
#    'end': {'x': 50, 'y': 0},
#    'goal': {'x': 50, 'y': 98.1}},
#   'reversedPeriodTime': 1,
#   'reversedPeriodTimeSeconds': 608,
#   'periodTimeSeconds': 292,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Bruno Fernandes',
#    'slug': 'bruno-fernandes',
#    'shortName': 'B. Fernandes',
#    'position': 'M',
#    'jerseyNumber': '8',
#    'userCount': 182893,
#    'id': 288205,
#    'fieldTranslations': {'nameTranslation': {'ar': 'برونو فيرنانديز',
#      'hi': 'ब्रूनो फर्नांडीस',
#      'bn': 'ব্রুনো ফার্নান্দেস'},
#     'shortNameTranslation': {'ar': 'ب. فرنانديز',
#      'hi': 'बी. फर्नांडीस',
#      'bn': 'বি. ফার্নান্দেস'}}},
#   'isHome': False,
#   'shotType': 'goal',
#   'goalType': 'regular',
#   'situation': 'assisted',
#   'playerCoordinates': {'x': 18.7, 'y': 52.8, 'z': 0},
#   'bodyPart': 'right-foot',
#   'goalMouthLocation': 'low-left',
#   'goalMouthCoordinates': {'x': 0, 'y': 54.1, 'z': 14.6},
#   'xg': 0.10261054337025,
#   'xgot': 0.63882112503052,
#   'id': 4600149,
#   'time': 90,
#   'timeSeconds': 5349,
#   'draw': {'start': {'x': 52.8, 'y': 18.7},
#    'end': {'x': 45.9, 'y': 0},
#    'goal': {'x': 45.9, 'y': 85.4}},
#   'reversedPeriodTime': 1,
#   'reversedPeriodTimeSeconds': 51,
#   'periodTimeSeconds': 2649,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Casemiro',
#    'firstName': '',
#    'lastName': '',
#    'slug': 'casemiro',
#    'shortName': 'Casemiro',
#    'position': 'M',
#    'jerseyNumber': '18',
#    'userCount': 111981,
#    'id': 122951,
#    'fieldTranslations': {'nameTranslation': {'ar': 'كاسيميرو',
#      'hi': 'कैसेमिरो',
#      'bn': 'ক্যাসেমিরো'},
#     'shortNameTranslation': {'ar': 'كاسيميرو',
#      'hi': 'कैसेमिरो',
#      'bn': 'ক্যাসেমিরো'}}},
#   'isHome': False,
#   'shotType': 'block',
#   'situation': 'assisted',
#   'playerCoordinates': {'x': 26.8, 'y': 57.5, 'z': 0},
#   'bodyPart': 'right-foot',
#   'goalMouthLocation': 'low-centre',
#   'goalMouthCoordinates': {'x': 0, 'y': 51.4, 'z': 6.9},
#   'blockCoordinates': {'x': 12, 'y': 53.4, 'z': 0},
#   'xg': 0.020909611135721,
#   'xgot': 0,
#   'id': 4600106,
#   'time': 79,
#   'timeSeconds': 4707,
#   'draw': {'start': {'x': 57.5, 'y': 26.8},
#    'block': {'x': 53.4, 'y': 12},
#    'end': {'x': 48.6, 'y': 0},
#    'goal': {'x': 48.6, 'y': 93.1}},
#   'reversedPeriodTime': 12,
#   'reversedPeriodTimeSeconds': 693,
#   'periodTimeSeconds': 2007,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Facundo Buonanotte',
#    'firstName': 'Facundo Buonanotte',
#    'lastName': '',
#    'slug': 'facundo-buonanotte',
#    'shortName': 'F. Buonanotte',
#    'position': 'M',
#    'jerseyNumber': '40',
#    'userCount': 6902,
#    'id': 1117025,
#    'fieldTranslations': {'nameTranslation': {'ar': 'فاكوندو بونانوتي',
#      'hi': 'फ़ाकंडो बुओनानोट्टे',
#      'bn': 'ফ্যাকুন্ডো বুওনানোত্তে'},
#     'shortNameTranslation': {'ar': 'ف. بونانوتي',
#      'hi': 'एफ. बुओनानोट्टे',
#      'bn': 'এফ. বুওনানোট'}}},
#   'isHome': True,
#   'shotType': 'block',
#   'situation': 'assisted',
#   'playerCoordinates': {'x': 10.7, 'y': 53, 'z': 0},
#   'bodyPart': 'right-foot',
#   'goalMouthLocation': 'low-centre',
#   'goalMouthCoordinates': {'x': 0, 'y': 50.6, 'z': 4.2},
#   'blockCoordinates': {'x': 7.1, 'y': 52.3, 'z': 0},
#   'xg': 0.16043667495251,
#   'xgot': 0,
#   'id': 4600095,
#   'time': 75,
#   'timeSeconds': 4483,
#   'draw': {'start': {'x': 53, 'y': 10.7},
#    'block': {'x': 52.3, 'y': 7.1},
#    'end': {'x': 49.4, 'y': 0},
#    'goal': {'x': 49.4, 'y': 95.8}},
#   'reversedPeriodTime': 16,
#   'reversedPeriodTimeSeconds': 917,
#   'periodTimeSeconds': 1783,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Luke Thomas',
#    'slug': 'luke-thomas',
#    'shortName': 'L. Thomas',
#    'position': 'D',
#    'jerseyNumber': '33',
#    'userCount': 497,
#    'id': 991584,
#    'fieldTranslations': {'nameTranslation': {'ar': 'لوك توماس',
#      'hi': 'ल्यूक थॉमस',
#      'bn': 'লুক থমাস'},
#     'shortNameTranslation': {'ar': 'ل. توماس',
#      'hi': 'एल. थॉमस',
#      'bn': 'এল. থমাস'}}},
#   'isHome': True,
#   'shotType': 'block',
#   'situation': 'assisted',
#   'playerCoordinates': {'x': 25.9, 'y': 41.9, 'z': 0},
#   'bodyPart': 'left-foot',
#   'goalMouthLocation': 'low-centre',
#   'goalMouthCoordinates': {'x': 0, 'y': 50.1, 'z': 19},
#   'blockCoordinates': {'x': 24.2, 'y': 42.4, 'z': 0},
#   'xg': 0.016907373443246,
#   'xgot': 0,
#   'id': 4600075,
#   'time': 70,
#   'timeSeconds': 4163,
#   'draw': {'start': {'x': 41.9, 'y': 25.9},
#    'block': {'x': 42.4, 'y': 24.2},
#    'end': {'x': 49.9, 'y': 0},
#    'goal': {'x': 49.9, 'y': 81}},
#   'reversedPeriodTime': 21,
#   'reversedPeriodTimeSeconds': 1237,
#   'periodTimeSeconds': 1463,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Alejandro Garnacho',
#    'firstName': '',
#    'lastName': '',
#    'slug': 'alejandro-garnacho',
#    'shortName': 'A. Garnacho',
#    'position': 'M',
#    'jerseyNumber': '17',
#    'userCount': 147677,
#    'id': 1135873,
#    'fieldTranslations': {'nameTranslation': {'ar': 'أليخاندرو غارناتشو',
#      'hi': 'एलेजांद्रो गार्नाचो',
#      'bn': 'আলেজান্দ্রো গার্নাচো'},
#     'shortNameTranslation': {'ar': 'أ. غارناتشو',
#      'hi': 'ए. गार्नाचो',
#      'bn': 'এ. গার্নাচো'}}},
#   'isHome': False,
#   'shotType': 'goal',
#   'goalType': 'regular',
#   'situation': 'assisted',
#   'playerCoordinates': {'x': 12, 'y': 59.1, 'z': 0},
#   'bodyPart': 'right-foot',
#   'goalMouthLocation': 'low-right',
#   'goalMouthCoordinates': {'x': 0, 'y': 46.3, 'z': 7},
#   'xg': 0.062079336494207,
#   'xgot': 0.24153129756451,
#   'id': 4600066,
#   'time': 67,
#   'timeSeconds': 4013,
#   'draw': {'start': {'x': 59.1, 'y': 12},
#    'end': {'x': 53.7, 'y': 0},
#    'goal': {'x': 53.7, 'y': 93}},
#   'reversedPeriodTime': 24,
#   'reversedPeriodTimeSeconds': 1387,
#   'periodTimeSeconds': 1313,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Diogo Dalot',
#    'firstName': '',
#    'lastName': '',
#    'slug': 'diogo-dalot',
#    'shortName': 'D. Dalot',
#    'position': 'D',
#    'jerseyNumber': '20',
#    'userCount': 21092,
#    'id': 843200,
#    'fieldTranslations': {'nameTranslation': {'ar': 'ديوغو دالوت',
#      'hi': 'डिओगो डालोत',
#      'bn': 'ডিওগো ডালট'},
#     'shortNameTranslation': {'ar': 'د. دالوت',
#      'hi': 'डी. डालोत',
#      'bn': 'ডি. ডালট'}}},
#   'isHome': False,
#   'shotType': 'block',
#   'situation': 'assisted',
#   'playerCoordinates': {'x': 14, 'y': 32, 'z': 0},
#   'bodyPart': 'right-foot',
#   'goalMouthLocation': 'low-centre',
#   'goalMouthCoordinates': {'x': 0, 'y': 51.5, 'z': 19},
#   'blockCoordinates': {'x': 12.7, 'y': 33.6, 'z': 0},
#   'xg': 0.031824562698603,
#   'xgot': 0,
#   'id': 4600068,
#   'time': 67,
#   'timeSeconds': 3992,
#   'draw': {'start': {'x': 32, 'y': 14},
#    'block': {'x': 33.6, 'y': 12.7},
#    'end': {'x': 48.5, 'y': 0},
#    'goal': {'x': 48.5, 'y': 81}},
#   'reversedPeriodTime': 24,
#   'reversedPeriodTimeSeconds': 1408,
#   'periodTimeSeconds': 1292,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Bruno Fernandes',
#    'slug': 'bruno-fernandes',
#    'shortName': 'B. Fernandes',
#    'position': 'M',
#    'jerseyNumber': '8',
#    'userCount': 182893,
#    'id': 288205,
#    'fieldTranslations': {'nameTranslation': {'ar': 'برونو فيرنانديز',
#      'hi': 'ब्रूनो फर्नांडीस',
#      'bn': 'ব্রুনো ফার্নান্দেস'},
#     'shortNameTranslation': {'ar': 'ب. فرنانديز',
#      'hi': 'बी. फर्नांडीस',
#      'bn': 'বি. ফার্নান্দেস'}}},
#   'isHome': False,
#   'shotType': 'block',
#   'situation': 'assisted',
#   'playerCoordinates': {'x': 31, 'y': 36.8, 'z': 0},
#   'bodyPart': 'right-foot',
#   'goalMouthLocation': 'low-centre',
#   'goalMouthCoordinates': {'x': 0, 'y': 51.7, 'z': 19},
#   'blockCoordinates': {'x': 28.5, 'y': 37.7, 'z': 0},
#   'xg': 0.011741313152015,
#   'xgot': 0,
#   'id': 4600063,
#   'time': 66,
#   'timeSeconds': 3907,
#   'draw': {'start': {'x': 36.8, 'y': 31},
#    'block': {'x': 37.7, 'y': 28.5},
#    'end': {'x': 48.3, 'y': 0},
#    'goal': {'x': 48.3, 'y': 81}},
#   'reversedPeriodTime': 25,
#   'reversedPeriodTimeSeconds': 1493,
#   'periodTimeSeconds': 1207,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Alejandro Garnacho',
#    'firstName': '',
#    'lastName': '',
#    'slug': 'alejandro-garnacho',
#    'shortName': 'A. Garnacho',
#    'position': 'M',
#    'jerseyNumber': '17',
#    'userCount': 147677,
#    'id': 1135873,
#    'fieldTranslations': {'nameTranslation': {'ar': 'أليخاندرو غارناتشو',
#      'hi': 'एलेजांद्रो गार्नाचो',
#      'bn': 'আলেজান্দ্রো গার্নাচো'},
#     'shortNameTranslation': {'ar': 'أ. غارناتشو',
#      'hi': 'ए. गार्नाचो',
#      'bn': 'এ. গার্নাচো'}}},
#   'isHome': False,
#   'shotType': 'save',
#   'situation': 'corner',
#   'playerCoordinates': {'x': 13.8, 'y': 70.3, 'z': 0},
#   'bodyPart': 'right-foot',
#   'goalMouthLocation': 'low-left',
#   'goalMouthCoordinates': {'x': 0, 'y': 52.1, 'z': 4.4},
#   'blockCoordinates': {'x': 1.2, 'y': 52.2, 'z': 0},
#   'xg': 0.020430004224181,
#   'xgot': 0.054308965802193,
#   'id': 4600054,
#   'time': 62,
#   'timeSeconds': 3698,
#   'draw': {'start': {'x': 70.3, 'y': 13.8},
#    'block': {'x': 52.2, 'y': 1.2},
#    'end': {'x': 47.9, 'y': 0},
#    'goal': {'x': 47.9, 'y': 95.6}},
#   'reversedPeriodTime': 29,
#   'reversedPeriodTimeSeconds': 1702,
#   'periodTimeSeconds': 998,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Toby Collyer',
#    'firstName': 'Toby Collyer',
#    'lastName': '',
#    'slug': 'toby-collyer',
#    'shortName': 'T. Collyer',
#    'position': 'M',
#    'jerseyNumber': '43',
#    'userCount': 4521,
#    'id': 1084356},
#   'isHome': False,
#   'shotType': 'miss',
#   'situation': 'corner',
#   'playerCoordinates': {'x': 5.4, 'y': 48.5, 'z': 0},
#   'bodyPart': 'other',
#   'goalMouthLocation': 'right',
#   'goalMouthCoordinates': {'x': 0, 'y': 26.2, 'z': 11.1},
#   'blockCoordinates': {'x': 4, 'y': 53.8, 'z': 0},
#   'xg': 0.17188990116119,
#   'xgot': 0,
#   'id': 4600056,
#   'time': 62,
#   'timeSeconds': 3694,
#   'draw': {'start': {'x': 48.5, 'y': 5.4},
#    'block': {'x': 53.8, 'y': 4},
#    'end': {'x': 73.8, 'y': 0},
#    'goal': {'x': 73.8, 'y': 88.9}},
#   'reversedPeriodTime': 29,
#   'reversedPeriodTimeSeconds': 1706,
#   'periodTimeSeconds': 994,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Christian Eriksen',
#    'slug': 'christian-eriksen',
#    'shortName': 'C. Eriksen',
#    'position': 'M',
#    'jerseyNumber': '14',
#    'userCount': 30661,
#    'id': 105734,
#    'fieldTranslations': {'nameTranslation': {'ar': 'كريستيان إريكسن',
#      'hi': 'क्रिस्टियन एरिक्सन',
#      'bn': 'ক্রিশ্চিয়ান এরিকসেন'},
#     'shortNameTranslation': {'ar': 'ك. إريكسن',
#      'hi': 'सी. एरिक्सन',
#      'bn': 'সি. এরিকসেন'}}},
#   'isHome': False,
#   'shotType': 'block',
#   'situation': 'assisted',
#   'playerCoordinates': {'x': 23.5, 'y': 53.2, 'z': 0},
#   'bodyPart': 'right-foot',
#   'goalMouthLocation': 'low-centre',
#   'goalMouthCoordinates': {'x': 0, 'y': 50, 'z': 19},
#   'blockCoordinates': {'x': 22.5, 'y': 53.1, 'z': 0},
#   'xg': 0.023890597745776,
#   'xgot': 0,
#   'id': 4600053,
#   'time': 61,
#   'timeSeconds': 3642,
#   'draw': {'start': {'x': 53.2, 'y': 23.5},
#    'block': {'x': 53.1, 'y': 22.5},
#    'end': {'x': 50, 'y': 0},
#    'goal': {'x': 50, 'y': 81}},
#   'reversedPeriodTime': 30,
#   'reversedPeriodTimeSeconds': 1758,
#   'periodTimeSeconds': 942,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Christian Eriksen',
#    'slug': 'christian-eriksen',
#    'shortName': 'C. Eriksen',
#    'position': 'M',
#    'jerseyNumber': '14',
#    'userCount': 30661,
#    'id': 105734,
#    'fieldTranslations': {'nameTranslation': {'ar': 'كريستيان إريكسن',
#      'hi': 'क्रिस्टियन एरिक्सन',
#      'bn': 'ক্রিশ্চিয়ান এরিকসেন'},
#     'shortNameTranslation': {'ar': 'ك. إريكسن',
#      'hi': 'सी. एरिक्सन',
#      'bn': 'সি. এরিকসেন'}}},
#   'isHome': False,
#   'shotType': 'miss',
#   'situation': 'assisted',
#   'playerCoordinates': {'x': 28.4, 'y': 46.7, 'z': 0},
#   'bodyPart': 'right-foot',
#   'goalMouthLocation': 'close-left',
#   'goalMouthCoordinates': {'x': 0, 'y': 58.8, 'z': 6.9},
#   'blockCoordinates': {'x': 2.2, 'y': 43.1, 'z': 0},
#   'xg': 0.030677504837513,
#   'xgot': 0,
#   'id': 4600027,
#   'time': 56,
#   'timeSeconds': 3340,
#   'draw': {'start': {'x': 46.7, 'y': 28.4},
#    'block': {'x': 43.1, 'y': 2.2},
#    'end': {'x': 41.2, 'y': 0},
#    'goal': {'x': 41.2, 'y': 93.1}},
#   'reversedPeriodTime': 35,
#   'reversedPeriodTimeSeconds': 2060,
#   'periodTimeSeconds': 640,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Jamie Vardy',
#    'slug': 'jamie-vardy',
#    'shortName': 'J. Vardy',
#    'position': 'F',
#    'jerseyNumber': '9',
#    'userCount': 21184,
#    'id': 173827,
#    'fieldTranslations': {'nameTranslation': {'ar': 'جيمي فاردي',
#      'hi': 'जेमी वर्डी',
#      'bn': 'জেমি ভার্ডি'},
#     'shortNameTranslation': {'ar': 'ج. فاردي',
#      'hi': 'जे. वर्डी',
#      'bn': 'জে. ভার্ডি'}}},
#   'isHome': True,
#   'shotType': 'block',
#   'situation': 'assisted',
#   'playerCoordinates': {'x': 9.7, 'y': 42.5, 'z': 0},
#   'bodyPart': 'head',
#   'goalMouthLocation': 'low-centre',
#   'goalMouthCoordinates': {'x': 0, 'y': 50.1, 'z': 19},
#   'blockCoordinates': {'x': 8.4, 'y': 43.5, 'z': 0},
#   'xg': 0.035044740885496,
#   'xgot': 0,
#   'id': 4600039,
#   'time': 55,
#   'timeSeconds': 3272,
#   'draw': {'start': {'x': 42.5, 'y': 9.7},
#    'block': {'x': 43.5, 'y': 8.4},
#    'end': {'x': 49.9, 'y': 0},
#    'goal': {'x': 49.9, 'y': 81}},
#   'reversedPeriodTime': 36,
#   'reversedPeriodTimeSeconds': 2128,
#   'periodTimeSeconds': 572,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Boubakary Soumaré',
#    'firstName': '',
#    'lastName': '',
#    'slug': 'boubakary-soumare',
#    'shortName': 'B. Soumaré',
#    'position': 'M',
#    'jerseyNumber': '24',
#    'userCount': 1384,
#    'id': 887581,
#    'fieldTranslations': {'nameTranslation': {'ar': 'بوباكاري سوماري',
#      'hi': 'बौबाकरी सौमारे',
#      'bn': 'বুবাকারি সৌমারে'},
#     'shortNameTranslation': {'ar': 'ب. سوماري',
#      'hi': 'बी. सौमारे',
#      'bn': 'বি. সৌমারে'}}},
#   'isHome': True,
#   'shotType': 'block',
#   'situation': 'assisted',
#   'playerCoordinates': {'x': 21.6, 'y': 58.5, 'z': 0},
#   'bodyPart': 'right-foot',
#   'goalMouthLocation': 'low-centre',
#   'goalMouthCoordinates': {'x': 0, 'y': 50.2, 'z': 19},
#   'blockCoordinates': {'x': 18, 'y': 57, 'z': 0},
#   'xg': 0.035473864525557,
#   'xgot': 0,
#   'id': 4600025,
#   'time': 55,
#   'timeSeconds': 3265,
#   'draw': {'start': {'x': 58.5, 'y': 21.6},
#    'block': {'x': 57, 'y': 18},
#    'end': {'x': 49.8, 'y': 0},
#    'goal': {'x': 49.8, 'y': 81}},
#   'reversedPeriodTime': 36,
#   'reversedPeriodTimeSeconds': 2135,
#   'periodTimeSeconds': 565,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Patson Daka',
#    'firstName': '',
#    'lastName': '',
#    'slug': 'patson-daka',
#    'shortName': 'P. Daka',
#    'position': 'F',
#    'jerseyNumber': '20',
#    'userCount': 13154,
#    'id': 865057,
#    'fieldTranslations': {'nameTranslation': {'ar': 'باتسون داكا',
#      'hi': 'पैटसन डाका',
#      'bn': 'প্যাটসন ডাকা'},
#     'shortNameTranslation': {'ar': 'ب. داكا',
#      'hi': 'पी. डाका',
#      'bn': 'পি. ডাকা'}}},
#   'isHome': True,
#   'shotType': 'miss',
#   'situation': 'fast-break',
#   'playerCoordinates': {'x': 3.2, 'y': 60.5, 'z': 0},
#   'bodyPart': 'right-foot',
#   'goalMouthLocation': 'right',
#   'goalMouthCoordinates': {'x': 0, 'y': 36, 'z': 11.1},
#   'xg': 0.10129973292351,
#   'xgot': 0,
#   'id': 4599991,
#   'time': 48,
#   'timeSeconds': 2822,
#   'draw': {'start': {'x': 60.5, 'y': 3.2},
#    'end': {'x': 64, 'y': 0},
#    'goal': {'x': 64, 'y': 88.9}},
#   'reversedPeriodTime': 43,
#   'reversedPeriodTimeSeconds': 2578,
#   'periodTimeSeconds': 122,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Patson Daka',
#    'firstName': '',
#    'lastName': '',
#    'slug': 'patson-daka',
#    'shortName': 'P. Daka',
#    'position': 'F',
#    'jerseyNumber': '20',
#    'userCount': 13154,
#    'id': 865057,
#    'fieldTranslations': {'nameTranslation': {'ar': 'باتسون داكا',
#      'hi': 'पैटसन डाका',
#      'bn': 'প্যাটসন ডাকা'},
#     'shortNameTranslation': {'ar': 'ب. داكا',
#      'hi': 'पी. डाका',
#      'bn': 'পি. ডাকা'}}},
#   'isHome': True,
#   'shotType': 'miss',
#   'situation': 'assisted',
#   'playerCoordinates': {'x': 29.6, 'y': 46.8, 'z': 0},
#   'bodyPart': 'left-foot',
#   'goalMouthLocation': 'right',
#   'goalMouthCoordinates': {'x': 0, 'y': 38.8, 'z': 9.7},
#   'xg': 0.035557109862566,
#   'xgot': 0,
#   'id': 4599921,
#   'time': 44,
#   'timeSeconds': 2618,
#   'draw': {'start': {'x': 46.8, 'y': 29.6},
#    'end': {'x': 61.2, 'y': 0},
#    'goal': {'x': 61.2, 'y': 90.3}},
#   'reversedPeriodTime': 2,
#   'reversedPeriodTimeSeconds': 82,
#   'periodTimeSeconds': 2618,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Bilal El Khannouss',
#    'firstName': 'Bilal',
#    'lastName': 'El Khannouss',
#    'slug': 'bilal-el-khannouss',
#    'shortName': 'B. E. Khannouss',
#    'position': 'M',
#    'jerseyNumber': '11',
#    'userCount': 20639,
#    'id': 1126569,
#    'fieldTranslations': {'nameTranslation': {'ar': 'بلال الخنوس',
#      'hi': 'बिलाल अल खन्नौस',
#      'bn': 'বিলাল এল খানৌস'},
#     'shortNameTranslation': {'ar': 'ب. أ. خنوس',
#      'hi': 'बी.ई. खन्नौस',
#      'bn': 'বি. ই. খানৌস'}}},
#   'isHome': True,
#   'shotType': 'block',
#   'situation': 'regular',
#   'playerCoordinates': {'x': 13.2, 'y': 32.9, 'z': 0},
#   'bodyPart': 'right-foot',
#   'goalMouthLocation': 'low-centre',
#   'goalMouthCoordinates': {'x': 0, 'y': 51.3, 'z': 19},
#   'blockCoordinates': {'x': 8.3, 'y': 38.8, 'z': 0},
#   'xg': 0.060561802238226,
#   'xgot': 0,
#   'id': 4599917,
#   'time': 43,
#   'timeSeconds': 2579,
#   'draw': {'start': {'x': 32.9, 'y': 13.2},
#    'block': {'x': 38.8, 'y': 8.3},
#    'end': {'x': 48.7, 'y': 0},
#    'goal': {'x': 48.7, 'y': 81}},
#   'reversedPeriodTime': 3,
#   'reversedPeriodTimeSeconds': 121,
#   'periodTimeSeconds': 2579,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Patson Daka',
#    'firstName': '',
#    'lastName': '',
#    'slug': 'patson-daka',
#    'shortName': 'P. Daka',
#    'position': 'F',
#    'jerseyNumber': '20',
#    'userCount': 13154,
#    'id': 865057,
#    'fieldTranslations': {'nameTranslation': {'ar': 'باتسون داكا',
#      'hi': 'पैटसन डाका',
#      'bn': 'প্যাটসন ডাকা'},
#     'shortNameTranslation': {'ar': 'ب. داكا',
#      'hi': 'पी. डाका',
#      'bn': 'পি. ডাকা'}}},
#   'isHome': True,
#   'shotType': 'block',
#   'situation': 'assisted',
#   'playerCoordinates': {'x': 15.6, 'y': 43.8, 'z': 0},
#   'bodyPart': 'right-foot',
#   'goalMouthLocation': 'low-left',
#   'goalMouthCoordinates': {'x': 0, 'y': 52.3, 'z': 19},
#   'blockCoordinates': {'x': 10.3, 'y': 45.1, 'z': 0},
#   'xg': 0.14835047721863,
#   'xgot': 0,
#   'id': 4599916,
#   'time': 43,
#   'timeSeconds': 2577,
#   'draw': {'start': {'x': 43.8, 'y': 15.6},
#    'block': {'x': 45.1, 'y': 10.3},
#    'end': {'x': 47.7, 'y': 0},
#    'goal': {'x': 47.7, 'y': 81}},
#   'reversedPeriodTime': 3,
#   'reversedPeriodTimeSeconds': 123,
#   'periodTimeSeconds': 2577,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Bruno Fernandes',
#    'slug': 'bruno-fernandes',
#    'shortName': 'B. Fernandes',
#    'position': 'M',
#    'jerseyNumber': '8',
#    'userCount': 182893,
#    'id': 288205,
#    'fieldTranslations': {'nameTranslation': {'ar': 'برونو فيرنانديز',
#      'hi': 'ब्रूनो फर्नांडीस',
#      'bn': 'ব্রুনো ফার্নান্দেস'},
#     'shortNameTranslation': {'ar': 'ب. فرنانديز',
#      'hi': 'बी. फर्नांडीस',
#      'bn': 'বি. ফার্নান্দেস'}}},
#   'isHome': False,
#   'shotType': 'miss',
#   'situation': 'set-piece',
#   'playerCoordinates': {'x': 21.9, 'y': 46.4, 'z': 0},
#   'bodyPart': 'right-foot',
#   'goalMouthLocation': 'high',
#   'goalMouthCoordinates': {'x': 0, 'y': 44.2, 'z': 84.7},
#   'xg': 0.031974527984858,
#   'xgot': 0,
#   'id': 4599910,
#   'time': 41,
#   'timeSeconds': 2447,
#   'draw': {'start': {'x': 46.4, 'y': 21.9},
#    'end': {'x': 55.8, 'y': 0},
#    'goal': {'x': 55.8, 'y': 15.3}},
#   'reversedPeriodTime': 5,
#   'reversedPeriodTimeSeconds': 253,
#   'periodTimeSeconds': 2447,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Rasmus Højlund',
#    'slug': 'rasmus-hojlund',
#    'shortName': 'R. Højlund',
#    'position': 'F',
#    'jerseyNumber': '9',
#    'userCount': 71812,
#    'id': 1086417,
#    'fieldTranslations': {'nameTranslation': {'ar': 'راسموس هويجلوند',
#      'hi': 'रस्मस होजलंड',
#      'bn': 'রাসমাস হলান্ড'},
#     'shortNameTranslation': {'ar': 'راسموس هوجلوند',
#      'hi': 'रासमस होजलंड',
#      'bn': 'রাসমাস হলান্ড'}}},
#   'isHome': False,
#   'shotType': 'goal',
#   'goalType': 'regular',
#   'situation': 'fast-break',
#   'playerCoordinates': {'x': 8.3, 'y': 65.4, 'z': 0},
#   'bodyPart': 'right-foot',
#   'goalMouthLocation': 'low-left',
#   'goalMouthCoordinates': {'x': 0, 'y': 53.6, 'z': 2.5},
#   'xg': 0.13871614634991,
#   'xgot': 0.71319180727005,
#   'id': 4599830,
#   'time': 28,
#   'timeSeconds': 1639,
#   'draw': {'start': {'x': 65.4, 'y': 8.3},
#    'end': {'x': 46.4, 'y': 0},
#    'goal': {'x': 46.4, 'y': 97.5}},
#   'reversedPeriodTime': 18,
#   'reversedPeriodTimeSeconds': 1061,
#   'periodTimeSeconds': 1639,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Christian Eriksen',
#    'slug': 'christian-eriksen',
#    'shortName': 'C. Eriksen',
#    'position': 'M',
#    'jerseyNumber': '14',
#    'userCount': 30661,
#    'id': 105734,
#    'fieldTranslations': {'nameTranslation': {'ar': 'كريستيان إريكسن',
#      'hi': 'क्रिस्टियन एरिक्सन',
#      'bn': 'ক্রিশ্চিয়ান এরিকসেন'},
#     'shortNameTranslation': {'ar': 'ك. إريكسن',
#      'hi': 'सी. एरिक्सन',
#      'bn': 'সি. এরিকসেন'}}},
#   'isHome': False,
#   'shotType': 'post',
#   'situation': 'corner',
#   'playerCoordinates': {'x': 15.1, 'y': 20.3, 'z': 0},
#   'bodyPart': 'right-foot',
#   'goalMouthLocation': 'right',
#   'goalMouthCoordinates': {'x': 0, 'y': 44.7, 'z': 30.4},
#   'xg': 0.016547836363316,
#   'xgot': 0,
#   'id': 4599816,
#   'time': 23,
#   'timeSeconds': 1363,
#   'draw': {'start': {'x': 20.3, 'y': 15.1},
#    'end': {'x': 55.3, 'y': 0},
#    'goal': {'x': 55.3, 'y': 69.6}},
#   'reversedPeriodTime': 23,
#   'reversedPeriodTimeSeconds': 1337,
#   'periodTimeSeconds': 1363,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Bruno Fernandes',
#    'slug': 'bruno-fernandes',
#    'shortName': 'B. Fernandes',
#    'position': 'M',
#    'jerseyNumber': '8',
#    'userCount': 182893,
#    'id': 288205,
#    'fieldTranslations': {'nameTranslation': {'ar': 'برونو فيرنانديز',
#      'hi': 'ब्रूनो फर्नांडीस',
#      'bn': 'ব্রুনো ফার্নান্দেস'},
#     'shortNameTranslation': {'ar': 'ب. فرنانديز',
#      'hi': 'बी. फर्नांडीस',
#      'bn': 'বি. ফার্নান্দেস'}}},
#   'isHome': False,
#   'shotType': 'block',
#   'situation': 'regular',
#   'playerCoordinates': {'x': 18.5, 'y': 49.5, 'z': 0},
#   'bodyPart': 'right-foot',
#   'goalMouthLocation': 'low-right',
#   'goalMouthCoordinates': {'x': 0, 'y': 47.4, 'z': 19},
#   'blockCoordinates': {'x': 13.3, 'y': 50.4, 'z': 0},
#   'xg': 0.071820646524429,
#   'xgot': 0,
#   'id': 4599788,
#   'time': 22,
#   'timeSeconds': 1316,
#   'draw': {'start': {'x': 49.5, 'y': 18.5},
#    'block': {'x': 50.4, 'y': 13.3},
#    'end': {'x': 52.6, 'y': 0},
#    'goal': {'x': 52.6, 'y': 81}},
#   'reversedPeriodTime': 24,
#   'reversedPeriodTimeSeconds': 1384,
#   'periodTimeSeconds': 1316,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Alejandro Garnacho',
#    'firstName': '',
#    'lastName': '',
#    'slug': 'alejandro-garnacho',
#    'shortName': 'A. Garnacho',
#    'position': 'M',
#    'jerseyNumber': '17',
#    'userCount': 147677,
#    'id': 1135873,
#    'fieldTranslations': {'nameTranslation': {'ar': 'أليخاندرو غارناتشو',
#      'hi': 'एलेजांद्रो गार्नाचो',
#      'bn': 'আলেজান্দ্রো গার্নাচো'},
#     'shortNameTranslation': {'ar': 'أ. غارناتشو',
#      'hi': 'ए. गार्नाचो',
#      'bn': 'এ. গার্নাচো'}}},
#   'isHome': False,
#   'shotType': 'save',
#   'situation': 'corner',
#   'playerCoordinates': {'x': 21.4, 'y': 69.4, 'z': 0},
#   'bodyPart': 'right-foot',
#   'goalMouthLocation': 'low-centre',
#   'goalMouthCoordinates': {'x': 0, 'y': 49.3, 'z': 10.8},
#   'blockCoordinates': {'x': 2, 'y': 52.7, 'z': 0},
#   'xg': 0.017613371834159,
#   'xgot': 0.0098451506346464,
#   'id': 4599768,
#   'time': 19,
#   'timeSeconds': 1110,
#   'draw': {'start': {'x': 69.4, 'y': 21.4},
#    'block': {'x': 52.7, 'y': 2},
#    'end': {'x': 50.7, 'y': 0},
#    'goal': {'x': 50.7, 'y': 89.2}},
#   'reversedPeriodTime': 27,
#   'reversedPeriodTimeSeconds': 1590,
#   'periodTimeSeconds': 1110,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Manuel Ugarte',
#    'slug': 'manuel-ugarte',
#    'shortName': 'M. Ugarte',
#    'position': 'M',
#    'jerseyNumber': '25',
#    'userCount': 15689,
#    'id': 846425,
#    'fieldTranslations': {'nameTranslation': {'ar': 'مانويل أوغارتي',
#      'hi': 'मैनुअल उगार्टे',
#      'bn': 'ম্যানুয়েল উগার্তে'},
#     'shortNameTranslation': {'ar': 'م. أوغارتي',
#      'hi': 'एम. उगार्टे',
#      'bn': 'এম. উগার্তে'}}},
#   'isHome': False,
#   'shotType': 'miss',
#   'situation': 'assisted',
#   'playerCoordinates': {'x': 24.5, 'y': 31.9, 'z': 0},
#   'bodyPart': 'right-foot',
#   'goalMouthLocation': 'high-right',
#   'goalMouthCoordinates': {'x': 0, 'y': 40.2, 'z': 69.4},
#   'xg': 0.025978589430451,
#   'xgot': 0,
#   'id': 4599723,
#   'time': 11,
#   'timeSeconds': 629,
#   'draw': {'start': {'x': 31.9, 'y': 24.5},
#    'end': {'x': 59.8, 'y': 0},
#    'goal': {'x': 59.8, 'y': 30.6}},
#   'reversedPeriodTime': 35,
#   'reversedPeriodTimeSeconds': 2071,
#   'periodTimeSeconds': 629,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Manuel Ugarte',
#    'slug': 'manuel-ugarte',
#    'shortName': 'M. Ugarte',
#    'position': 'M',
#    'jerseyNumber': '25',
#    'userCount': 15689,
#    'id': 846425,
#    'fieldTranslations': {'nameTranslation': {'ar': 'مانويل أوغارتي',
#      'hi': 'मैनुअल उगार्टे',
#      'bn': 'ম্যানুয়েল উগার্তে'},
#     'shortNameTranslation': {'ar': 'م. أوغارتي',
#      'hi': 'एम. उगार्टे',
#      'bn': 'এম. উগার্তে'}}},
#   'isHome': False,
#   'shotType': 'miss',
#   'situation': 'throw-in-set-piece',
#   'playerCoordinates': {'x': 18.3, 'y': 69.2, 'z': 0},
#   'bodyPart': 'right-foot',
#   'goalMouthLocation': 'high',
#   'goalMouthCoordinates': {'x': 0, 'y': 46.1, 'z': 62.5},
#   'xg': 0.031524680554867,
#   'xgot': 0,
#   'id': 4599685,
#   'time': 9,
#   'timeSeconds': 499,
#   'draw': {'start': {'x': 69.2, 'y': 18.3},
#    'end': {'x': 53.9, 'y': 0},
#    'goal': {'x': 53.9, 'y': 37.5}},
#   'reversedPeriodTime': 37,
#   'reversedPeriodTimeSeconds': 2201,
#   'periodTimeSeconds': 499,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Rasmus Højlund',
#    'slug': 'rasmus-hojlund',
#    'shortName': 'R. Højlund',
#    'position': 'F',
#    'jerseyNumber': '9',
#    'userCount': 71812,
#    'id': 1086417,
#    'fieldTranslations': {'nameTranslation': {'ar': 'راسموس هويجلوند',
#      'hi': 'रस्मस होजलंड',
#      'bn': 'রাসমাস হলান্ড'},
#     'shortNameTranslation': {'ar': 'راسموس هوجلوند',
#      'hi': 'रासमस होजलंड',
#      'bn': 'রাসমাস হলান্ড'}}},
#   'isHome': False,
#   'shotType': 'miss',
#   'situation': 'assisted',
#   'playerCoordinates': {'x': 10.6, 'y': 50, 'z': 0},
#   'bodyPart': 'head',
#   'goalMouthLocation': 'right',
#   'goalMouthCoordinates': {'x': 0, 'y': 37.1, 'z': 20.8},
#   'blockCoordinates': {'x': 3.1, 'y': 57.4, 'z': 0},
#   'xg': 0.04499388858676,
#   'xgot': 0,
#   'id': 4599652,
#   'time': 6,
#   'timeSeconds': 340,
#   'draw': {'start': {'x': 50, 'y': 10.6},
#    'block': {'x': 57.4, 'y': 3.1},
#    'end': {'x': 62.9, 'y': 0},
#    'goal': {'x': 62.9, 'y': 79.2}},
#   'reversedPeriodTime': 40,
#   'reversedPeriodTimeSeconds': 2360,
#   'periodTimeSeconds': 340,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Jamie Vardy',
#    'slug': 'jamie-vardy',
#    'shortName': 'J. Vardy',
#    'position': 'F',
#    'jerseyNumber': '9',
#    'userCount': 21184,
#    'id': 173827,
#    'fieldTranslations': {'nameTranslation': {'ar': 'جيمي فاردي',
#      'hi': 'जेमी वर्डी',
#      'bn': 'জেমি ভার্ডি'},
#     'shortNameTranslation': {'ar': 'ج. فاردي',
#      'hi': 'जे. वर्डी',
#      'bn': 'জে. ভার্ডি'}}},
#   'isHome': True,
#   'shotType': 'save',
#   'situation': 'assisted',
#   'playerCoordinates': {'x': 11.4, 'y': 39.7, 'z': 0},
#   'bodyPart': 'right-foot',
#   'goalMouthLocation': 'high-left',
#   'goalMouthCoordinates': {'x': 0, 'y': 52.6, 'z': 20.9},
#   'blockCoordinates': {'x': 1, 'y': 47.7, 'z': 0},
#   'xg': 0.27265387773514,
#   'xgot': 0.23939791321754,
#   'id': 4599634,
#   'time': 4,
#   'timeSeconds': 205,
#   'draw': {'start': {'x': 39.7, 'y': 11.4},
#    'block': {'x': 47.7, 'y': 1},
#    'end': {'x': 47.4, 'y': 0},
#    'goal': {'x': 47.4, 'y': 79.1}},
#   'reversedPeriodTime': 42,
#   'reversedPeriodTimeSeconds': 2495,
#   'periodTimeSeconds': 205,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Rasmus Højlund',
#    'slug': 'rasmus-hojlund',
#    'shortName': 'R. Højlund',
#    'position': 'F',
#    'jerseyNumber': '9',
#    'userCount': 71812,
#    'id': 1086417,
#    'fieldTranslations': {'nameTranslation': {'ar': 'راسموس هويجلوند',
#      'hi': 'रस्मस होजलंड',
#      'bn': 'রাসমাস হলান্ড'},
#     'shortNameTranslation': {'ar': 'راسموس هوجلوند',
#      'hi': 'रासमस होजलंड',
#      'bn': 'রাসমাস হলান্ড'}}},
#   'isHome': False,
#   'shotType': 'miss',
#   'situation': 'throw-in-set-piece',
#   'playerCoordinates': {'x': 11.9, 'y': 43.4, 'z': 0},
#   'bodyPart': 'left-foot',
#   'goalMouthLocation': 'close-left',
#   'goalMouthCoordinates': {'x': 0, 'y': 57, 'z': 11.1},
#   'xg': 0.057159684598446,
#   'xgot': 0,
#   'id': 4599621,
#   'time': 1,
#   'timeSeconds': 54,
#   'draw': {'start': {'x': 43.4, 'y': 11.9},
#    'end': {'x': 43, 'y': 0},
#    'goal': {'x': 43, 'y': 88.9}},
#   'reversedPeriodTime': 45,
#   'reversedPeriodTimeSeconds': 2646,
#   'periodTimeSeconds': 54,
#   'incidentType': 'shot'}]

# %%
for i in shotmap:
    print (i['player']['name'])
# Out:
# Jamie Vardy
# Harry Winks
# Bruno Fernandes
# Casemiro
# Facundo Buonanotte
# Luke Thomas
# Alejandro Garnacho
# Diogo Dalot
# Bruno Fernandes
# Alejandro Garnacho
# Toby Collyer
# Christian Eriksen
# Christian Eriksen
# Jamie Vardy
# Boubakary Soumaré
# Patson Daka
# Patson Daka
# Bilal El Khannouss
# Patson Daka
# Bruno Fernandes
# Rasmus Højlund
# Christian Eriksen
# Bruno Fernandes
# Alejandro Garnacho
# Manuel Ugarte
# Manuel Ugarte
# Rasmus Højlund
# Jamie Vardy
# Rasmus Højlund
